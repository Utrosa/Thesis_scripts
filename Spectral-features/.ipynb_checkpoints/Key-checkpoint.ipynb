# %% [markdown]
# # Nearest Key Estimation (Weiss, 2021)

# %% [markdown]
# #### Loading.

# %%
# Load what you need.
import os
import numpy as np
import pandas as pd
from pdf_tonality import pdf_tonality as pdft

# %% [markdown]
# #### Specify the directory.
