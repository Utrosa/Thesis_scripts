# %%
# Obtain: mean number of pitches per participant & song form & improvised song.
s2 = pd.read_csv("C:/Users/monik/Documents/Paris/Internship/Analyses/Pilot-Data/Weiss-Data/Weiss_data_111_SONG_FORM.csv",
                 index_col=0)
subject = 111

### data_Weiss['NOTE'] = mean_midi_notes
### data_Weiss['DURATION'] = note_durations

# print(f'Number of pitches across all songs for participant {subject}: \nmean \t: {s2[s2['NOTE']].mean()}, \
# \nminimum : {s2[s2['NOTE']].min()}, \nmaximum : {s2[s2['NOTE']].max()}')

# mean_per_song = s_IMPROV['MIDI_NOTE'].agg(['sum', 'min', 'max']).astype('int')
# print(f'The mean number of pitches across all songs and all participants is:\n{mean_per_song}.')

# mean_per_participant = s_IMPROV['MIDI_NOTE'].agg(['sum', 'min', 'max']).astype('int')
# print(f'The mean number of pitches across all songs and all participants is:\n{mean_per_participant}.')

# mean_per_song_participant = s_IMPROV['MIDI_NOTE'].agg(['sum', 'min', 'max']).astype('int')
# print(f'The mean number of pitches across all songs and all participants is:\n{mean_per_song_participant}.')

# Does the mean number of pitches change over time (1-30 songs vs 1st half and 2nd half)?

# Obtain: mean pitch range per participant & song form & improvised song
# Does the pitch range change depending on the song form?
# Does the pitch range change over time (1-30 songs vs 1st half and 2nd half)?

# Obtain: mean number of pitch classes per participant & song form & improvised song
