# %%
# Do hearing improv experience, occupation, education, or birthplace indicate differences between participants / age groups?

# %%
# Get average improvisation task satisfaction.

# %%
# Report difficulties experienced by participants.

# %%
# Do the potential demographic differences predict amount of difficulty improvisating songs?
